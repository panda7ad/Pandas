# %% [markdown]
# ### basic syntax

# %%
import pandas as pd

# %%
import pandas as pd
x=[3,4,5,6,7]
var=pd.Series(x)
print(var)
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# dtype: int64

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=["a","b","c"],index=["x","y","z"])

# %%
df
# Out:
#    a  b  c
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
result=pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/bios.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 result=pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/bios.csv')
#
# File c:\Users\Adarsh Patel\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
result.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %%
result.head(5)
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
result.describe
# Out:
# <bound method NDFrame.describe of         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
result.columns
# Out:
# Index(['athlete_id', 'name', 'born_date', 'born_city', 'born_region',
#        'born_country', 'NOC', 'height_cm', 'weight_kg', 'died_date'],
#       dtype='object')

# %%
result.athlete_id
# Out:
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
#            ...
# 145495    149222
# 145496    149223
# 145497    149224
# 145498    149225
# 145499    149814
# Name: athlete_id, Length: 145500, dtype: int64

# %%
result.loc[0:10,"name"]
# Out:
# 0       Jean-François Blanchy
# 1              Arnaud Boetsch
# 2                Jean Borotra
# 3             Jacques Brugnon
# 4                Albert Canet
# 5           Nicolas Chatelain
# 6               Patrick Chila
# 7                Henri Cochet
# 8               Marcel Cousin
# 9          Guy de la Chapelle
# 10    Élie, Comte de Lastours
# Name: name, dtype: object

# %%
result.sort_values(["height_cm"],ascending=True)
# Out:
#         athlete_id                   name   born_date           born_city  \
# 4515          4530          Lyton Mphande  1963-05-14                 NaN
# 28619        28832        Rosario Briones  1953-10-05     San Luis Potosí
# 4516          4531          Helman Palije  1967-06-24                 NaN
# 4664          4681       Salvador Miranda  1949-09-13                 NaN
# 4517          4532         Boston Simbeye  1959-12-24                 NaN
# ...            ...                    ...         ...                 ...
# 145490      149217            Sin Ye-Chan  1995-06-13                 NaN
# 145491      149218          Matthew Wepke  1989-12-05                 NaN
# 145492      149219  Carlos García-Ordóñez  1927-04-24  La Habana (Havana)
# 145493      149220     Landysh Falyakhova  1998-08-31    Dva Polya Artash
# 145499      149814          Bill Phillips  1913-07-15        Dulwich Hill
#
#                  born_region born_country                NOC  height_cm  \
# ...

# %%
result.iloc[1:10,4:10]
# Out:
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25
# 5                 Somme          FRA  France      181.0       70.0         NaN
# 6               Essonne          FRA  France      180.0       73.0         NaN
# 7                 Rhône          FRA  France        NaN        NaN  1987-04-02
# 8                  Gard          FRA  France        NaN        NaN  1986-08-01
# 9                  Cher          FRA  France        NaN        NaN  1923-08-27

# %%
result.loc[1:10]
# Out:
#     athlete_id                     name   born_date          born_city  \
# 1            2           Arnaud Boetsch  1969-04-01             Meulan
# 2            3             Jean Borotra  1898-08-13           Biarritz
# 3            4          Jacques Brugnon  1895-05-11        Paris VIIIe
# 4            5             Albert Canet  1878-04-17         Wandsworth
# 5            6        Nicolas Chatelain  1970-01-13             Amiens
# 6            7            Patrick Chila  1969-11-27        Ris-Orangis
# 7            8             Henri Cochet  1901-12-14       Villeurbanne
# 8            9            Marcel Cousin  1896-08-04              Nîmes
# 9           10       Guy de la Chapelle  1868-07-16  Farges-Allichamps
# 10          11  Élie, Comte de Lastours  1874-08-12            Orgeval
#
#              born_region born_country     NOC  height_cm  weight_kg  \
# 1               Yvelines          FRA  France      183.0       76.0
# ...

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
result[(result["height_cm"]>215) & (result["weight_kg"]==110)]
# Out:
#         athlete_id                name   born_date         born_city  \
# 5716          5739            Uwe Blab  1962-03-26  München (Munich)
# 7188          7226  Vladimir Tkachenko  1957-09-20         Golovinka
# 82100        82753       Frédéric Weis  1977-06-22        Thionville
# 112312      113568        Stanko Barać  1986-08-13            Mostar
# 112337      113593       Hamed Haddadi  1985-05-19             Ahvaz
# 120266      122147        Zhang Zhaoxu  1987-11-18           Binzhou
# 121694      123709         Salah Mejri  1986-06-15          Jendouba
#
#                             born_region born_country  \
# 5716                             Bayern          GER
# 7188                     Krasnodar Kray          RUS
# 82100                           Moselle          FRA
# 112312  Hercegovačko-neretvanski kanton          BIH
# 112337                        Khuzestan          IRI
# 120266                         Shandong          CHN
# ...

# %%
result[result['name'].str.contains("pandey",case=False)]
# Out:
#        athlete_id                  name   born_date born_city born_region  \
# 58295       58709  Lakhshmi Kant Pandey  1936-01-01       NaN         NaN
# 58296       58710   Tarashkeswar Pandey  1936-01-01       NaN         NaN
# 73358       73923     Raj Kumari Pandey  1969-12-13       NaN         NaN
#
#       born_country    NOC  height_cm  weight_kg died_date
# 58295          NaN  India        NaN        NaN       NaN
# 58296          NaN  India        NaN        NaN       NaN
# 73358          NaN  Nepal      165.0       54.0       NaN

# %%
result[result['born_country'].isin(["USA","FRA","GBR"])]
# Out:
#         athlete_id                   name   born_date      born_city  \
# 0                1  Jean-François Blanchy  1886-12-12       Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01         Meulan
# 2                3           Jean Borotra  1898-08-13       Biarritz
# 3                4        Jacques Brugnon  1895-05-11    Paris VIIIe
# 4                5           Albert Canet  1878-04-17     Wandsworth
# ...            ...                    ...         ...            ...
# 145454      149180          Anna Hoffmann  2000-03-28        Madison
# 145457      149183         Alix Wilkinson  2000-08-02  Mammoth Lakes
# 145467      149194            Elisa Nakab  1998-05-08       Briançon
# 145468      149195      Justin Abdelkader  1987-02-25       Muskegon
# 145498      149225         André Foussard  1899-05-19          Niort
#
#                  born_region born_country            NOC  height_cm  \
# 0                    Gironde          FRA         France        NaN
# ...

# %%
resultnew=result.copy()

# %%
resultnew['first_name']=resultnew['name'].str.split(' ').str[0]

# %%
resultnew.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name
# 0  1960-10-02  Jean-François
# 1         NaN         Arnaud
# 2  1994-07-17           Jean
# 3  1978-03-20        Jacques
# 4  1930-07-25         Albert

# %%
resultnew['born_datetime']=pd.to_datetime(resultnew['born_date'])
resultnew.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime
# 0  1960-10-02  Jean-François    1886-12-12
# 1         NaN         Arnaud    1969-04-01
# 2  1994-07-17           Jean    1898-08-13
# ...

# %%
resultnew.isna().sum()
# Out:
# athlete_id            0
# name                  0
# born_date          1807
# born_city         34592
# born_region       34592
# born_country      34592
# NOC                   1
# height_cm         38849
# weight_kg         43430
# died_date        111560
# first_name            0
# born_datetime      1807
# dtype: int64

# %%
resultnew['height_cm'].fillna(resultnew['height_cm'].mean())
resultnew.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 resultnew['height_cm'].fillna(resultnew['height_cm'].mean())
#       2 resultnew.head(10)
#
# NameError: name 'resultnew' is not defined

# %%
resultnew['height_cm'] = resultnew['height_cm'].fillna(resultnew['height_cm'].mean())
resultnew
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC   height_cm  weight_kg  \
# ...
