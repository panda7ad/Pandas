# %% [markdown]
# ### Series from list

# %%
import pandas as pd
import numpy as np

# %%
country=['india','usa','china','australia']

pd.Series(country)
# Out:
# 0        india
# 1          usa
# 2        china
# 3    australia
# dtype: str

# %%
runs=[12,222,32,34,34,54,5,343,]
pd.Series(runs)
# Out:
# 0     12
# 1    222
# 2     32
# 3     34
# 4     34
# 5     54
# 6      5
# 7    343
# dtype: int64

# %%
sub=['math','eng','hindi','phy']
marks=[52,89,75,78]

mark_series=pd.Series(marks,index=sub,name='MARKS OF AD')
mark_series
# Out:
# math     52
# eng      89
# hindi    75
# phy      78
# Name: MARKS OF AD, dtype: int64

# %%
mark_series.dtype
# Out:
# dtype('int64')

# %%
mark_series.is_unique
# Out:
# True

# %%
mark_series.index
# Out:
# Index(['math', 'eng', 'hindi', 'phy'], dtype='str')

# %%
mark_series.values
# Out:
# array([52, 89, 75, 78])

# %% [markdown]
# ### Series using read_csv

# %%
subscount = pd.read_csv(r'datasets-session-16\subs.csv').squeeze() #squeeze turns dataframe into series

# %%
type(subscount)
# Out:
# pandas.Series

# %%
movies = pd.read_csv(
    'datasets-session-16/bollywood.csv',
    index_col='movie'
).squeeze()

#HERE WE HAVE TO EXPLITCITLY MENTIONED INDEX_COL 
# BECAUSE WE HAD TWO COLUMN AND SQUEEZ WOULD HAVE FAILED+

# %%
type(movies)
# Out:
# pandas.Series

# %%
vk= pd.read_csv(r'C:\Users\Adarsh Patel\Desktop\PANDAS\datasets-session-16\kohli_ipl.csv',index_col='match_no').squeeze()

# %% [markdown]
# ### series function

# %%
vk.head(10) #give top 10
# Out:
# match_no
# 1      1
# 2     23
# 3     13
# 4     12
# 5      1
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# Name: runs, dtype: int64

# %%
vk.tail(10) #gives bottom 10
# Out:
# match_no
# 206     0
# 207     0
# 208     9
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
vk.sample() #gives data randomaly
# Out:
# match_no
# 67    3
# Name: runs, dtype: int64

# %%
vk.sample(5) # can specfiy the number
# Out:
# match_no
# 170    18
# 52     70
# 31     34
# 142    31
# 68     73
# Name: runs, dtype: int64

# %%
movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Tanishaa Mukerji     1
# Tanuja               1
# Ankit                1
# Rakhee Gulzar        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
vk.sort_values(ascending=False) #method chaining
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 120    100
# 164    100
#       ...
# 93       0
# 130      0
# 206      0
# 207      0
# 211      0
# Name: runs, Length: 215, dtype: int64

# %%
vk.sort_values(ascending=False).head(10)
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 120    100
# 164    100
# 82      99
# 81      93
# 145     92
# 178     90
# 160     84
# Name: runs, dtype: int64

# %%
vk.sort_values(ascending=False).head(10).values
# Out:
# array([113, 109, 108, 100, 100,  99,  93,  92,  90,  84])

# %%
vk.sort_values(ascending=False).head(10).values[0]
# Out:
# np.int64(113)

# %%
#inplace changes in original series

# %%
movies.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: str

# %%
## extracting a movies of single actor

actor_name = "Salman Khan"
actor_entries = movies[movies == actor_name].sort_index()
print(actor_entries)
# Out:
# movie
# Bajrangi Bhaijaan                   Salman Khan
# Bodyguard (2011 Hindi film)         Salman Khan
# Dabangg                             Salman Khan
# Dabangg 2                           Salman Khan
# Dabangg 3                           Salman Khan
# Dil Ne Jise Apna Kahaa              Salman Khan
# Ek Tha Tiger                        Salman Khan
# Garv: Pride & Honour                Salman Khan
# Jaan-E-Mann                         Salman Khan
# Jai Ho (film)                       Salman Khan
# Kick (2014 film)                    Salman Khan
# Kyon Ki                             Salman Khan
# London Dreams                       Salman Khan
# Lucky: No Time for Love             Salman Khan
# Main Aurr Mrs Khanna                Salman Khan
# Maine Pyaar Kyun Kiya?              Salman Khan
# Marigold (2007 film)                Salman Khan
# Mujhse Shaadi Karogi                Salman Khan
# Partner (2007 film)                 Salman Khan
# ...

# %%
zero_runs=vk[vk>50].count
print(zero_runs)
# Out:
# <bound method Series.count of match_no
# 34      58
# 41      71
# 44      56
# 45      67
# 52      70
# 57      57
# 68      73
# 71      51
# 73      58
# 74      65
# 80      57
# 81      93
# 82      99
# 85      56
# 97      67
# 99      73
# 103     51
# 104     62
# 110     82
# 116     75
# 117     79
# 119     80
# 120    100
# 122     52
# 123    108
# 126    109
# 127     75
# 128    113
# 129     54
# 131     54
# 132     62
# 134     64
# 137     55
# 141     58
# 144     57
# 145     92
# 148     68
# 152     70
# 160     84
# 162     67
# 164    100
# 175     72
# 178     90
# 188     72
# 197     51
# 198     53
# 209     58
# 213     73
# Name: runs, dtype: int64>

# %% [markdown]
# ### Series Maths Method

# %%
# count()
# sum() --> value
# product 
# mean
# median 
# mode
# std
# var
# min/max
# describe --> summary of all the stats

# %% [markdown]
# ### SERIES INDEXING

# %%
# integer indexing--->[]
# negative indexing if index are string
# slicing---> [5:16]
# negative allowed

# %%
#fancy indexing

vk[[1,3,4,5]]
# Out:
# match_no
# 1     1
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %% [markdown]
# ### EDITING SERIES

# %%
mark_series
# Out:
# math     52
# eng      89
# hindi    75
# phy      78
# Name: MARKS OF AD, dtype: int64

# %%
mark_series['math']=100

# %%
mark_series
# Out:
# math     100
# eng       89
# hindi     75
# phy       78
# Name: MARKS OF AD, dtype: int64

# %%
mark_series
# Out:
# math     100
# eng       89
# hindi     75
# phy       78
# Name: MARKS OF AD, dtype: int64

# %%
#type convo

list(mark_series)
# Out:
# [100, 89, 75, 78]

# %%
#membership operation(works on index values not value) , looping(values) everythig is applicable for index --> .index

# %%
# vk run more then 50 
# boolean indexing
vk[vk>50]
# Out:
# match_no
# 34      58
# 41      71
# 44      56
# 45      67
# 52      70
# 57      57
# 68      73
# 71      51
# 73      58
# 74      65
# 80      57
# 81      93
# 82      99
# 85      56
# 97      67
# 99      73
# 103     51
# 104     62
# 110     82
# 116     75
# 117     79
# 119     80
# 120    100
# 122     52
# 123    108
# 126    109
# 127     75
# 128    113
# 129     54
# 131     54
# 132     62
# 134     64
# 137     55
# 141     58
# 144     57
# 145     92
# 148     68
# 152     70
# 160     84
# 162     67
# 164    100
# 175     72
# 178     90
# 188     72
# 197     51
# 198     53
# 209     58
# 213     73
# Name: runs, dtype: int64

# %%
vk[vk>50].size
# Out:
# 48

# %%
subscount[subscount>200]
# Out:
# 165    225
# 166    249
# 167    265
# 168    306
# 169    261
# 170    222
# 225    224
# 226    254
# 227    214
# 228    236
# 229    261
# 230    247
# 231    207
# 232    254
# 233    301
# 234    233
# 240    202
# 246    259
# 248    213
# 249    210
# 252    216
# 275    228
# 276    237
# 277    276
# 279    290
# 280    295
# 281    245
# 282    241
# 283    267
# 284    269
# 285    211
# 287    206
# 288    202
# 290    236
# 291    222
# 292    203
# 312    230
# 318    244
# 324    243
# 325    227
# 326    259
# 330    396
# 331    312
# 332    268
# 333    229
# 337    221
# 338    225
# 339    221
# 340    202
# 344    276
# 345    258
# 346    219
# 347    212
# 351    220
# 354    204
# 358    210
# 359    209
# 360    231
# 361    226
# Name: Subscribers gained, dtype: int64

# %%
subscount[subscount>200].size
# Out:
# 59

# %% [markdown]
# ### GRAPH

# %%
vk.plot()
# Out:
# <Axes: xlabel='match_no'>

# %%
movies_int=movies.value_counts().head(20)

# %%
movies_int.plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %% [markdown]
# ### IMPORTANT SERIES METHOD

# %%
#astype
import sys

sys.getsizeof(vk)
# Out:
# 1884

# %%
#int64--->int16

vk.astype('int16')
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int16

# %%
sys.getsizeof(vk.astype('int16'))
# Out:
# 594

# %%
#between tells value between range

vk[vk.between(51,99)].size #-->(start to end) includes 51 and 99 too
# Out:
# 43

# %%
#clip converts all the data to given values

vk.clip(50,100)
# Out:
# match_no
# 1      50
# 2      50
# 3      50
# 4      50
# 5      50
#        ..
# 211    50
# 212    50
# 213    73
# 214    50
# 215    50
# Name: runs, Length: 215, dtype: int64

# %%
# duplicate

temp=pd.Series([1,1,3,4,4,2,3,4])
temp
# Out:
# 0    1
# 1    1
# 2    3
# 3    4
# 4    4
# 5    2
# 6    3
# 7    4
# dtype: int64

# %%
temp.drop_duplicates()
# Out:
# 0    1
# 2    3
# 3    4
# 5    2
# dtype: int64

# %%
#temp.duplicated()---> tells if duplicate exit .sum()-->total no of duplicate

# %%
temp=pd.Series([1,1,3,np.nan,4,2,np.nan,4])

# %%
temp.size #count nan value
# Out:
# 8

# %%
temp.count() #dosent count nan value
# Out:
# np.int64(6)

# %%
temp.isnull().sum() #-->number of missing value
# Out:
# np.int64(2)

# %%
temp.dropna() #--> removes the missing value
# Out:
# 0    1.0
# 1    1.0
# 2    3.0
# 4    4.0
# 5    2.0
# 7    4.0
# dtype: float64

# %%
temp.fillna(temp.mean()) #-->fil the missing value with given logic
# Out:
# 0    1.0
# 1    1.0
# 2    3.0
# 3    2.5
# 4    4.0
# 5    2.0
# 6    2.5
# 7    4.0
# dtype: float64

# %%
vk[(vk == 49) | (vk==99)]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
vk[vk.isin([49,99])] #-->simplify the logic
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
#apply -->helps to apply own logic

movies.apply(lambda x:x.split()[0].upper()) #-->split the surname by indexing getting fisrt name then converting it to upper
# Out:
# movie
# Uri: The Surgical Strike                  VICKY
# Battalion 609                             VICKY
# The Accidental Prime Minister (film)     ANUPAM
# Why Cheat India                          EMRAAN
# Evening Shadows                            MONA
#                                          ...
# Hum Tumhare Hain Sanam                     SHAH
# Aankhen (2002 film)                     AMITABH
# Saathiya (film)                           VIVEK
# Company (film)                             AJAY
# Awara Paagal Deewana                     AKSHAY
# Name: lead, Length: 1500, dtype: str

# %%
#copy

# %%
new=vk.head(10) #-->sometimes pandas send view then origanl changes safe to .copy() orignal remains intact

# %%
new
# Out:
# match_no
# 1      1
# 2     23
# 3     13
# 4     12
# 5      1
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# Name: runs, dtype: int64

# %%
new[1]
# Out:
# np.int64(1)

# %%
new[1]=1

# %%
vk.loc[1]=100 #--> changes in orignal data

# %%
vk
# Out:
# match_no
# 1      100
# 2       23
# 3       13
# 4       12
# 5        1
#       ...
# 211      0
# 212     20
# 213     73
# 214     25
# 215      7
# Name: runs, Length: 215, dtype: int64
