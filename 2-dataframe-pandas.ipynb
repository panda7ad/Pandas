# %%
import pandas as pd
import numpy as np

# %%
student={
    'name':['ad','aadi','ankit','rupesh'],
    'iq':[80,90,100,120],
    'marks':[100,80,90,70],
    'lpa':[10,7,9,20]
}
stud=pd.DataFrame(student)
stud.set_index('name',inplace=True)

# %%
stud
# Out:
#          iq  marks  lpa
# name
# ad       80    100   10
# aadi     90     80    7
# ankit   100     90    9
# rupesh  120     70   20

# %% [markdown]
# ### IMPORTING DATAFRAME

# %%
movies=pd.read_csv(r"datasets-session-16\movies.csv")

# %%
movies.head(10)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
# 5                           Soni (film)  tt6078866
# 6                         Fraud Saiyaan  tt5013008
# 7                            Bombairiya  tt4971258
# 8      Manikarnika: The Queen of Jhansi  tt6903440
# 9                      Thackeray (film)  tt7777196
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl=pd.read_csv("datasets-session-16/ipl-matches.csv")

# %%
ipl.head(10)
# Out:
#         ID         City        Date Season  MatchNumber  \
# 0  1312200    Ahmedabad  2022-05-29   2022        Final
# 1  1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198      Kolkata  2022-05-25   2022   Eliminator
# 3  1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116       Mumbai  2022-05-22   2022           70
# 5  1304115       Mumbai  2022-05-21   2022           69
# 6  1304114       Mumbai  2022-05-20   2022           68
# 7  1304113       Mumbai  2022-05-19   2022           67
# 8  1304112  Navi Mumbai  2022-05-18   2022           66
# 9  1304111       Mumbai  2022-05-17   2022           65
#
#                          Team1                        Team2  \
# 0             Rajasthan Royals               Gujarat Titans
# 1  Royal Challengers Bangalore             Rajasthan Royals
# 2  Royal Challengers Bangalore         Lucknow Super Giants
# 3             Rajasthan Royals               Gujarat Titans
# ...

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='str')

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='str')

# %%
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
ipl.sample(1)
# Out:
#          ID       City        Date Season MatchNumber  \
# 473  829745  Bangalore  2015-04-22   2015          20
#
#                            Team1                Team2                  Venue  \
# 473  Royal Challengers Bangalore  Chennai Super Kings  M Chinnaswamy Stadium
#
#                       TossWinner TossDecision SuperOver          WinningTeam  \
# 473  Royal Challengers Bangalore        field         N  Chennai Super Kings
#
#     WonBy  Margin method Player_of_Match  \
# 473  Runs    27.0    NaN        SK Raina
#
#                                           Team1Players  \
# 473  ['MS Bisla', 'RR Rossouw', 'V Kohli', 'KD Kart...
#
#                                           Team2Players    Umpire1  \
# 473  ['DR Smith', 'BB McCullum', 'SK Raina', 'MS Dh...  JD Cloete
#
#            Umpire2
# 473  C Shamshuddin

# %%
ipl.shape #(row,col)
# Out:
# (950, 20)

# %%
movies.shape
# Out:
# (1629, 18)

# %%
ipl.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    str
#  2   Date             950 non-null    str
#  3   Season           950 non-null    str
#  4   MatchNumber      950 non-null    str
#  5   Team1            950 non-null    str
#  6   Team2            950 non-null    str
#  7   Venue            950 non-null    str
#  8   TossWinner       950 non-null    str
#  9   TossDecision     950 non-null    str
#  10  SuperOver        946 non-null    str
#  11  WinningTeam      946 non-null    str
#  12  WonBy            950 non-null    str
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     str
#  15  Player_of_Match  946 non-null    str
#  16  Team1Players     950 non-null    str
#  17  Team2Players     950 non-null    str
# ...

# %%
# Select only columns with dtype 'string'
string_cols = ipl.select_dtypes(include="string").columns

# Convert them to object
ipl[string_cols] = ipl[string_cols].astype("object")

# %%
string_cols=movies.select_dtypes(include="string").columns
movies[string_cols]=movies[string_cols].astype("object")

# %%
movies.info() # provide info
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
ipl.describe() #ALL THE STATS
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
movies.isnull().sum() #tells missing value
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
#rename --> rename th col   movies.rename(columns={'orignal name':'new name'})

# %% [markdown]
# ### Math Methods

# %%
# you apply all the stats here

# %%
stud
# Out:
#          iq  marks  lpa
# name
# ad       80    100   10
# aadi     90     80    7
# ankit   100     90    9
# rupesh  120     70   20

# %%
#sum
stud.sum() #column
# Out:
# iq       390
# marks    340
# lpa       46
# dtype: int64

# %%
stud.sum(axis=1) ##rowwise
# Out:
# name
# ad        190
# aadi      177
# ankit     199
# rupesh    210
# dtype: int64

# %% [markdown]
# ### FETCHING COL FROM DATA

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='str')

# %%
#SINGLE COL

movies['imdb_votes']
# Out:
# 0       35112
# 1          73
# 2        5549
# 3        1891
# 4         280
#         ...
# 1624      278
# 1625      133
# 1626       13
# 1627       38
# 1628     2968
# Name: imdb_votes, Length: 1629, dtype: int64

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='str')

# %%
ipl['Venue']
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
#multiple columns

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='str')

# %%
movies[['release_date','title_x','imdb_rating']].head(10)
# Out:
#               release_date                               title_x  imdb_rating
# 0    11 January 2019 (USA)              Uri: The Surgical Strike          8.4
# 1  11 January 2019 (India)                         Battalion 609          4.1
# 2    11 January 2019 (USA)  The Accidental Prime Minister (film)          6.1
# 3    18 January 2019 (USA)                       Why Cheat India          6.0
# 4  11 January 2019 (India)                       Evening Shadows          7.3
# 5    18 January 2019 (USA)                           Soni (film)          7.2
# 6  18 January 2019 (India)                         Fraud Saiyaan          4.2
# 7  18 January 2019 (India)                            Bombairiya          4.3
# 8    25 January 2019 (USA)      Manikarnika: The Queen of Jhansi          6.5
# 9  25 January 2019 (India)                      Thackeray (film)          5.1

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='str')

# %%
ipl['WinningTeam']
# Out:
# 0                   Gujarat Titans
# 1                 Rajasthan Royals
# 2      Royal Challengers Bangalore
# 3                   Gujarat Titans
# 4                     Punjab Kings
#                   ...
# 945          Kolkata Knight Riders
# 946    Royal Challengers Bangalore
# 947               Delhi Daredevils
# 948            Chennai Super Kings
# 949          Kolkata Knight Riders
# Name: WinningTeam, Length: 950, dtype: object

# %%
ipl[['Team1','Team2','WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %% [markdown]
# ### FETCH ROW FROM DF

# %%
#ILOC- SEARCH USING INDEX POSITION
#LOC - SEARCHES USING INEX VALUES

# %%
movies.iloc[:5] # slicing same as python
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies.iloc[[1,4,5]] #fancy indexing
# Out:
#            title_x    imdb_id  \
# 1    Battalion 609  tt9472208
# 4  Evening Shadows  tt6028796
# 5      Soni (film)  tt6078866
#
#                                          poster_path  \
# 1                                                NaN
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                        wiki_link          title_y  \
# 1    https://en.wikipedia.org/wiki/Battalion_609    Battalion 609
# 4  https://en.wikipedia.org/wiki/Evening_Shadows  Evening Shadows
# 5      https://en.wikipedia.org/wiki/Soni_(film)             Soni
#
#     original_title  is_adult  year_of_release runtime genres  imdb_rating  \
# 1    Battalion 609         0             2019     131    War          4.1
# 4  Evening Shadows         0             2018     102  Drama          7.3
# 5             Soni         0             2018      97  Drama          7.2
#
# ...

# %%
stud
# Out:
#          iq  marks  lpa
# name
# ad       80    100   10
# aadi     90     80    7
# ankit   100     90    9
# rupesh  120     70   20

# %%
stud.loc['ad']
# Out:
# iq        80
# marks    100
# lpa       10
# Name: ad, dtype: int64

# %%
stud.loc['ad':'ankit'] #no exclusion
# Out:
#         iq  marks  lpa
# name
# ad      80    100   10
# aadi    90     80    7
# ankit  100     90    9

# %%
stud.loc[['ad','rupesh']]
# Out:
#          iq  marks  lpa
# name
# ad       80    100   10
# rupesh  120     70   20

# %%
#both col and row

# %%
movies.iloc[0:3,0:3] #[row,column]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0:2,'title_x':'poster_path'] # rem in loc by provide value not index
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# ### FILTERING THE DATA

# %%
ipl.loc[0:1]
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
#find all the final winner

mask=ipl['MatchNumber']=='Final'
ipl_winner=ipl[mask]
ipl_winner.head(2)
# Out:
#          ID       City        Date Season MatchNumber                Team1  \
# 0   1312200  Ahmedabad  2022-05-29   2022       Final     Rajasthan Royals
# 74  1254117      Dubai  2021-10-15   2021       Final  Chennai Super Kings
#
#                     Team2                                Venue  \
# 0          Gujarat Titans     Narendra Modi Stadium, Ahmedabad
# 74  Kolkata Knight Riders  Dubai International Cricket Stadium
#
#                TossWinner TossDecision SuperOver          WinningTeam  \
# 0        Rajasthan Royals          bat         N       Gujarat Titans
# 74  Kolkata Knight Riders        field         N  Chennai Super Kings
#
#       WonBy  Margin method Player_of_Match  \
# 0   Wickets     7.0    NaN       HH Pandya
# 74     Runs    27.0    NaN    F du Plessis
#
#                                          Team1Players  \
# 0   ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 74  ['RD Gaikwad', 'F du Plessis', 'RV Uthappa', '...
#
# ...

# %%
ipl_winner[['Season',"WinningTeam"]]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
#how many super over

so_ipl=ipl[ipl['SuperOver']=='Y'][['Team1','Team2','SuperOver']]
so_ipl
# Out:
#                            Team1                        Team2 SuperOver
# 114               Delhi Capitals          Sunrisers Hyderabad         Y
# 158        Kolkata Knight Riders          Sunrisers Hyderabad         Y
# 159               Mumbai Indians              Kings XI Punjab         Y
# 184  Royal Challengers Bangalore               Mumbai Indians         Y
# 192               Delhi Capitals              Kings XI Punjab         Y
# 203               Mumbai Indians          Sunrisers Hyderabad         Y
# 244        Kolkata Knight Riders               Delhi Capitals         Y
# 339                Gujarat Lions               Mumbai Indians         Y
# 474             Rajasthan Royals              Kings XI Punjab         Y
# 533        Kolkata Knight Riders             Rajasthan Royals         Y
# 608  Royal Challengers Bangalore             Delhi Daredevils         Y
# 621          Sunrisers Hyderabad  Royal Challengers Bangalore         Y
# ...

# %%
so_ipl.shape[0]
# Out:
# 14

# %%
#how many csk won in kolkata
ipl[(ipl['City']=='Kolkata') & (ipl['WinningTeam']=='Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
ipl.shape[0]
# Out:
# 950

# %%
#toss winner is match winner in percentage
(ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ipl.shape[0])*100
# Out:
# 51.473684210526315
